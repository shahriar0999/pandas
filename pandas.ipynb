# %% [markdown]
# <a href="https://colab.research.google.com/github/shahriar0999/pandas/blob/main/pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
titanic = sns.load_dataset('titanic')
ufo.to_csv('ufo_report.csv')
ufo.head()
# Out:
#                    City Colors Reported Shape Reported State             Time
# 0                Ithaca             NaN       TRIANGLE    NY   6/1/1930 22:00
# 1           Willingboro             NaN          OTHER    NJ  6/30/1930 20:00
# 2               Holyoke             NaN           OVAL    CO  2/15/1931 14:00
# 3               Abilene             NaN           DISK    KS   6/1/1931 13:00
# 4  New York Worlds Fair             NaN          LIGHT    NY  4/18/1933 19:00

# %%
# add a column in ufo dataframe

ufo['Location'] = ufo['City'] + ufo['State']

ufo.head()
# Out:
#                    City Colors Reported Shape Reported State             Time  \
# 0                Ithaca             NaN       TRIANGLE    NY   6/1/1930 22:00
# 1           Willingboro             NaN          OTHER    NJ  6/30/1930 20:00
# 2               Holyoke             NaN           OVAL    CO  2/15/1931 14:00
# 3               Abilene             NaN           DISK    KS   6/1/1931 13:00
# 4  New York Worlds Fair             NaN          LIGHT    NY  4/18/1933 19:00
#
#                  Location
# 0                IthacaNY
# 1           WillingboroNJ
# 2               HolyokeCO
# 3               AbileneKS
# 4  New York Worlds FairNY

# %% [markdown]
# ## Rename Column

# %%
ufo.rename(columns={'Colors Reported':'Colors_Reported', 'Shape Reported':'Shape_Reported'}).head()   ##First way to rename columns
# Out:
#                    City Colors_Reported Shape_Reported State             Time  \
# 0                Ithaca             NaN       TRIANGLE    NY   6/1/1930 22:00
# 1           Willingboro             NaN          OTHER    NJ  6/30/1930 20:00
# 2               Holyoke             NaN           OVAL    CO  2/15/1931 14:00
# 3               Abilene             NaN           DISK    KS   6/1/1931 13:00
# 4  New York Worlds Fair             NaN          LIGHT    NY  4/18/1933 19:00
#
#                  Location
# 0                IthacaNY
# 1           WillingboroNJ
# 2               HolyokeCO
# 3               AbileneKS
# 4  New York Worlds FairNY

# %%
ufo_cols = ['city', 'colors_reported', 'shaped_reported', 'state', 'time', 'location']   ## second way to rename columns
ufo.columns = ufo_cols
ufo.head()
# Out:
#                    city colors_reported shaped_reported state  \
# 0                Ithaca             NaN        TRIANGLE    NY
# 1           Willingboro             NaN           OTHER    NJ
# 2               Holyoke             NaN            OVAL    CO
# 3               Abilene             NaN            DISK    KS
# 4  New York Worlds Fair             NaN           LIGHT    NY
#
#               time                location
# 0   6/1/1930 22:00                IthacaNY
# 1  6/30/1930 20:00           WillingboroNJ
# 2  2/15/1931 14:00               HolyokeCO
# 3   6/1/1931 13:00               AbileneKS
# 4  4/18/1933 19:00  New York Worlds FairNY

# %%
## rename columns name
ufo.columns = ufo.columns.str.replace('_', ' ')
ufo.head()
# Out:
#                    city colors reported shaped reported state  \
# 0                Ithaca             NaN        TRIANGLE    NY
# 1           Willingboro             NaN           OTHER    NJ
# 2               Holyoke             NaN            OVAL    CO
# 3               Abilene             NaN            DISK    KS
# 4  New York Worlds Fair             NaN           LIGHT    NY
#
#               time                location
# 0   6/1/1930 22:00                IthacaNY
# 1  6/30/1930 20:00           WillingboroNJ
# 2  2/15/1931 14:00               HolyokeCO
# 3   6/1/1931 13:00               AbileneKS
# 4  4/18/1933 19:00  New York Worlds FairNY

# %%
## we can difine columns when we read csv
ufo_cols = ['city', 'colors_reported', 'shaped_reported', 'state', 'time', 'location']
ufo_reports = pd.read_csv('ufo_report.csv', names =ufo_cols)

ufo_reports.head()
# Out:
#    city colors_reported  shaped_reported           state   time  \
# 0   NaN            City  Colors Reported  Shape Reported  State
# 1   0.0          Ithaca              NaN        TRIANGLE     NY
# 2   1.0     Willingboro              NaN           OTHER     NJ
# 3   2.0         Holyoke              NaN            OVAL     CO
# 4   3.0         Abilene              NaN            DISK     KS
#
#           location
# 0             Time
# 1   6/1/1930 22:00
# 2  6/30/1930 20:00
# 3  2/15/1931 14:00
# 4   6/1/1931 13:00

# %% [markdown]
# ## Remove Columns from pandas dataframe

# %%
Fifa = pd.read_csv('fifa.csv')
Fifa.head(3)
# Out:
#    Unnamed: 0      id              name   rating  position   height    foot  \
# 0           0    1001      Gábor Király       69        GK      191   Right
# 1           1  100143      Frederik Boi       65         M      184   Right
# 2           2  100264   Tomasz Szewczuk       57         A      185   Right
#
#     rare  pace  shooting  passing  dribbling  defending  heading  diving  \
# 0      0                                                              70
# 1      0    61        65       63         59         62       62
# 2      0    65        54       43         53         55       74
#
#    handling  kicking  reflexes  speed   positioning
# 0        66       63        74     35          66.0
# 1                                               NaN
# 2                                               NaN

# %%
Fifa.drop('Unnamed: 0', axis=1, inplace=True)
Fifa.head()
# Out:
#        id                     name   rating  position   height    foot   rare  \
# 0    1001             Gábor Király       69        GK      191   Right      0
# 1  100143             Frederik Boi       65         M      184   Right      0
# 2  100264          Tomasz Szewczuk       57         A      185   Right      0
# 3  100325   Steeve Joseph-Reinette       63         D      180    Left      0
# 4  100326             Kamel Chafni       72         M      181   Right      0
#
#    pace  shooting  passing  dribbling  defending  heading  diving  handling  \
# 0                                                              70        66
# 1    61        65       63         59         62       62
# 2    65        54       43         53         55       74
# 3    68        38       51         46         64       71
# 4    75        64       67         72         57       66
#
#    kicking  reflexes  speed   positioning
# 0       63        74     35          66.0
# ...

# %%
# remove row from dataframe

Fifa.drop([0,1,2], inplace=True)   # by default axis=0 (rows) thats why we don't pass axis
Fifa.head()
# Out:
#        id                     name   rating  position   height    foot   rare  \
# 3  100325   Steeve Joseph-Reinette       63         D      180    Left      0
# 4  100326             Kamel Chafni       72         M      181   Right      0
# 5  100329           Abdoulaye Faye       72         D      187   Right      1
# 6  100330                José Saez       67         M      170   Right      0
# 7  100391          Laurent Delorge       67         M      179   Right      0
#
#    pace  shooting  passing  dribbling  defending  heading  diving  handling  \
# 3    68        38       51         46         64       71
# 4    75        64       67         72         57       66
# 5    50        37       47         43         76       82
# 6    53        60       65         61         64       60
# 7    76        58       67         64         63       56
#
#    kicking  reflexes  speed   positioning
# 3                                     NaN
# 4                                     NaN
# ...

# %% [markdown]
# ## Sorting Pandas DataFrame or Series

# %%
ufo.head()
# Out:
#                    City Colors Reported Shape Reported State             Time
# 0                Ithaca             NaN       TRIANGLE    NY   6/1/1930 22:00
# 1           Willingboro             NaN          OTHER    NJ  6/30/1930 20:00
# 2               Holyoke             NaN           OVAL    CO  2/15/1931 14:00
# 3               Abilene             NaN           DISK    KS   6/1/1931 13:00
# 4  New York Worlds Fair             NaN          LIGHT    NY  4/18/1933 19:00

# %%
ufo.City.sort_values(ascending=False).head(10)
# Out:
# 35450                 west morland
# 62941    wailea, mckenna, Maui, HI
# 47402                      various
# 59876                    vacaville
# 43967            unsure exact name
# 68534                         ucon
# 28455                         troy
# 28459                         troy
# 55636                     temecula
# 6001           south of the border
# Name: City, dtype: object

# %%
ufo['City'].sort_values(ascending=False).head(10)
# Out:
# 35450                 west morland
# 62941    wailea, mckenna, Maui, HI
# 47402                      various
# 59876                    vacaville
# 43967            unsure exact name
# 68534                         ucon
# 28455                         troy
# 28459                         troy
# 55636                     temecula
# 6001           south of the border
# Name: City, dtype: object

# %%
drink_cols = ['country', 'beer_servings', 'spirit_servings','wine_servings', 'total_litres_of_pure_alcohol', 'continent']
drink = pd.read_csv('drink.csv', names=drink_cols)
drink.head()
# Out:
#          country  beer_servings  spirit_servings  wine_servings  \
# NaN      country  beer_servings  spirit_servings  wine_servings
# 0.0  Afghanistan              0                0              0
# 1.0      Albania             89              132             54
# 2.0      Algeria             25                0             14
# 3.0      Andorra            245              138            312
#
#      total_litres_of_pure_alcohol  continent
# NaN  total_litres_of_pure_alcohol  continent
# 0.0                           0.0         AS
# 1.0                           4.9         EU
# 2.0                           0.7         AF
# 3.0                          12.4         EU

# %%
drink['country'].sort_values(ascending=False).head(10)
# Out:
# NaN             country
# 192.0          Zimbabwe
# 191.0            Zambia
# 190.0             Yemen
# 189.0           Vietnam
# 188.0         Venezuela
# 187.0           Vanuatu
# 186.0        Uzbekistan
# 185.0           Uruguay
# 182.0    United Kingdom
# Name: country, dtype: object

# %%
drink.sort_values('country', ascending=False).head(10)
# Out:
#               country  beer_servings  spirit_servings  wine_servings  \
# NaN           country  beer_servings  spirit_servings  wine_servings
# 192.0        Zimbabwe             64               18              4
# 191.0          Zambia             32               19              4
# 190.0           Yemen              6                0              0
# 189.0         Vietnam            111                2              1
# 188.0       Venezuela            333              100              3
# 187.0         Vanuatu             21               18             11
# 186.0      Uzbekistan             25              101              8
# 185.0         Uruguay            115               35            220
# 182.0  United Kingdom            219              126            195
#
#        total_litres_of_pure_alcohol  continent
# NaN    total_litres_of_pure_alcohol  continent
# 192.0                           4.7         AF
# 191.0                           2.5         AF
# ...

# %%
drink.sort_values(['beer_servings','total_litres_of_pure_alcohol'], ascending=False).head(10)
# Out:
#                  country  beer_servings  spirit_servings  wine_servings  \
# NaN              country  beer_servings  spirit_servings  wine_servings
# 169.0           Thailand             99              258              1
# 108.0          Mauritius             98               31             18
# 72.0              Guyana             93              302              1
# 43.0                Cuba             93              137              5
# 55.0   Equatorial Guinea             92                0            233
# 164.0          Swaziland             90                2              2
# 77.0               India              9              114              0
# 150.0            Senegal              9                1              7
# 70.0              Guinea              9                0              2
#
#        total_litres_of_pure_alcohol  continent
# NaN    total_litres_of_pure_alcohol  continent
# 169.0                           6.4         AS
# ...

# %% [markdown]
# ## Filtering row in Pandas DataFrame with Columns
